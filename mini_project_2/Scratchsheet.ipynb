# %% [markdown]
# # "Scratchsheet"
#
# Before writing up your final mini-project report, it's a good idea to explore your dataset and models here first on a "scratchsheet" notebook such as this. Then when you're finally ready to create your report, submit it in the `Mini_Project_2_YOURNAMEHERE.ipynb` file.
#
# I'm not expecting you to submit this "scratchsheet".

# %%
import pandas as pd
df = pd.read_csv("drugs.csv")

# %%
df[df.Year == 2018]
# Out:
#                     State  Year  Population.12-17  Population.18-25  \
# 816               Alabama  2018            371033            505103
# 817                Alaska  2018             57444             71183
# 818               Arizona  2018            562546            763917
# 819              Arkansas  2018            237382            312348
# 820            California  2018           3017701           4174962
# 821              Colorado  2018            433719            589317
# 822           Connecticut  2018            268807            383297
# 823              Delaware  2018             69325             92525
# 824  District of Columbia  2018             31910             86420
# 825               Florida  2018           1439529           1956426
# 826               Georgia  2018            868842           1107324
# 827                Hawaii  2018             95153            120820
# 828                 Idaho  2018            155001            183511
# ...
