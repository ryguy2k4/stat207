# %% [markdown]
# # "Scratchsheet"
#
# Before writing up your final mini-project report, it's probably a good idea to explore your dataset first on a "scratchsheet" notebook such as this. Then when you're finally ready to create your report, submit it in the `Mini_Project_1_YOURNAMEHERE.ipynb` file.
#
# I'm not expecting you to submit this "scratchsheet".

# %%
import pandas as pd

# %%
df = pd.read_csv("video_games.csv")
df.columns
# Out:
# Index(['Title', 'Features.Handheld?', 'Features.Max Players',
#        'Features.Multiplatform?', 'Features.Online?', 'Metadata.Genres',
#        'Metadata.Licensed?', 'Metadata.Publishers', 'Metadata.Sequel?',
#        'Metrics.Review Score', 'Metrics.Sales', 'Metrics.Used Price',
#        'Release.Console', 'Release.Rating', 'Release.Re-release?',
#        'Release.Year', 'Length.All PlayStyles.Average',
#        'Length.All PlayStyles.Leisure', 'Length.All PlayStyles.Median',
#        'Length.All PlayStyles.Polled', 'Length.All PlayStyles.Rushed',
#        'Length.Completionists.Average', 'Length.Completionists.Leisure',
#        'Length.Completionists.Median', 'Length.Completionists.Polled',
#        'Length.Completionists.Rushed', 'Length.Main + Extras.Average',
#        'Length.Main + Extras.Leisure', 'Length.Main + Extras.Median',
#        'Length.Main + Extras.Polled', 'Length.Main + Extras.Rushed',
#        'Length.Main Story.Average', 'Length.Main Story.Leisure',
# ...

# %%
df2 = df[['Title', 'Features.Handheld?', 'Features.Max Players',
       'Features.Multiplatform?', 'Features.Online?', 'Metadata.Genres',
       'Metadata.Licensed?', 'Metadata.Publishers', 'Metadata.Sequel?',
       'Metrics.Review Score', 'Metrics.Sales', 'Metrics.Used Price',
       'Release.Console', 'Release.Rating', 'Release.Re-release?',
       'Release.Year', 'Length.All PlayStyles.Average']]
df2
# Out:
#                          Title  Features.Handheld?  Features.Max Players  \
# 0            Super Mario 64 DS                True                     1
# 1       Lumines: Puzzle Fusion                True                     1
# 2           WarioWare Touched!                True                     2
# 3     Hot Shots Golf: Open Tee                True                     1
# 4                 Spider-Man 2                True                     1
# ...                        ...                 ...                   ...
# 1207    Secret Files: Tunguska                True                     1
# 1208            Fading Shadows                True                     1
# 1209         Hail to the Chimp                True                     1
# 1210    Secret Files: Tunguska                True                     2
# 1211            Chicken Hunter                True                     1
#
#       Features.Multiplatform?  Features.Online?  \
# ...

# %% [markdown]
# # How does `length` and `genre` affect `sales`

# %%
df2.isna().sum()
# Out:
# Title                              0
# Features.Handheld?                 0
# Features.Max Players               0
# Features.Multiplatform?            0
# Features.Online?                   0
# Metadata.Genres                    0
# Metadata.Licensed?                 0
# Metadata.Publishers              264
# Metadata.Sequel?                   0
# Metrics.Review Score               0
# Metrics.Sales                      0
# Metrics.Used Price                 0
# Release.Console                    0
# Release.Rating                     0
# Release.Re-release?                0
# Release.Year                       0
# Length.All PlayStyles.Average      0
# dtype: int64

# %%
df2["Metadata.Genres"].value_counts()

# Action
# Sports
# Strategy
# RPG
# Racing
# Simulation
# Adventure
# Educational
# Out:
# Metadata.Genres
# Action                                                  476
# Sports                                                  166
# Strategy                                                 62
# Action,Role-Playing (RPG)                                55
# Racing / Driving                                         53
# Role-Playing (RPG)                                       52
# Action,Strategy                                          45
# Action,Racing / Driving                                  40
# Simulation                                               30
# Action,Simulation                                        28
# Action,Adventure                                         28
# Adventure                                                21
# Role-Playing (RPG),Strategy                              20
# Action,Sports                                            20
# Racing / Driving,Sports                                  19
# ...

# %%
df2.corr(numeric_only=True)
# Out:
#                                Features.Handheld?  Features.Max Players  \
# Features.Handheld?                            NaN                   NaN
# Features.Max Players                          NaN              1.000000
# Features.Multiplatform?                       NaN                   NaN
# Features.Online?                              NaN                   NaN
# Metadata.Licensed?                            NaN                   NaN
# Metadata.Sequel?                              NaN                   NaN
# Metrics.Review Score                          NaN              0.078635
# Metrics.Sales                                 NaN              0.084581
# Metrics.Used Price                            NaN             -0.026943
# Release.Re-release?                           NaN                   NaN
# Release.Year                                  NaN              0.116508
# Length.All PlayStyles.Average                 NaN             -0.038211
#
# ...

# %%
df["Genre.Action"] = df["Metadata.Genres"].apply(lambda x: "Action" in x)
df["Genre.Sports"] = df["Metadata.Genres"].apply(lambda x: "Sports" in x)
df["Genre.Strategy"] = df["Metadata.Genres"].apply(lambda x: "Strategy" in x)
df["Genre.RPG"] = df["Metadata.Genres"].apply(lambda x: "Role-Playing (RPG)" in x)
df["Genre.Racing"] = df["Metadata.Genres"].apply(lambda x: "Racing / Driving" in x)
df["Genre.Simulation"] = df["Metadata.Genres"].apply(lambda x: "Simulation" in x)
df["Genre.Adventure"] = df["Metadata.Genres"].apply(lambda x: "Adventure" in x)
df["Genre.Educational"] = df["Metadata.Genres"].apply(lambda x: "Educational" in x)

df[["Genre.Action", "Genre.Sports", "Genre.Strategy", "Genre.RPG", "Genre.Racing", "Genre.Simulation", "Genre.Adventure", "Genre.Educational"]].sum()
